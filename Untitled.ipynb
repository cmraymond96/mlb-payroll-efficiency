# %%
print("Hello Baseball Analytics World!")
# Out:
# Hello Baseball Analytics World!

# %%
import sqlite3  # This connects Python to SQLite databases
import pandas as pd  # This handles data manipulation and analysis

# %%
# Create a connection to a new SQLite database
# This database will live in the same folder as your notebook
conn = sqlite3.connect('baseball_test.db')
print("Database connection successful!")
# Out:
# Database connection successful!
